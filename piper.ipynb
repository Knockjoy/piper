# %%
module_names='''
pygame
numpy
'''.strip()

# %%
# !rm -rf /content/req.txt and rm -rf /content/modules and rm -rf /content/download.zip
# !echo -e "{module_names}">> /content/req.txt
# !pip install -r /content/req.txt -t /content/modules
# !zip -r download.zip modules
from google.colab import files
files.download('download.zip')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached pygame-2.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
# ...
#   Using cached numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# ...
#   adding: modules/ (stored 0%)
#   adding: modules/pygame-2.3.0.dist-info/ (stored 0%)
#   adding: modules/pygame-2.3.0.dist-info/REQUESTED (stored 0%)
#   adding: modules/pygame-2.3.0.dist-info/top_level.txt (stored 0%)
#   adding: modules/pygame-2.3.0.dist-info/WHEEL (deflated 22%)
#   adding: modules/pygame-2.3.0.dist-info/INSTALLER (stored 0%)
#   adding: modules/pygame-2.3.0.dist-info/entry_points.txt (deflated 17%)
# ...
